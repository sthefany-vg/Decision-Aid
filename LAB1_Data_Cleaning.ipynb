# %% [markdown]
# <a href="https://colab.research.google.com/github/sthefany-vg/Decision-Aid/blob/main/LAB1_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAPPC - LAB 1 (2025 - 2026)
# ## Dataset preparation (cleaning + comorbidity encoding)
#
# In this notebook you will:
#
# 1. Load the dataset
# 2. Inspect initial size and print a table with **(column index, column name, dtype)**
# 3. Analyze missing values **per variable** and drop variables above a threshold
# 4. Analyze missing values **per subject (row)** and drop subjects above a threshold
# 5. Encode comorbidities into 6 aggregated variables
# 6. Save the final prepared dataset for the next labs
#
# **Outcome (3 classes):**
# - `0` = extubation failure
# - `1` = extubation success
# - `2` = death during ICU stay

# %% [markdown]
# ---
#
# ## 0) Setup
# Run this cell first.

# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %% [markdown]
# ---
#
# ## 1) Load the dataset

# %%
# === TODO: set your file path and sheet name ===
file_path = 'Dataset_DAPPC_2026.xlsx'
sheet_name = 'Dataset'

df = pd.read_excel(file_path, sheet_name=sheet_name)
df.head()
# Out:
#    subject_id   hadm_id   stay_id  ICU           ICU_intime  \
# 0    13710366  26676995  36043579    1  2172-04-05 04:00:00
# 1    12970079  23949170  36004625    1  2164-12-22 19:48:19
# 2    17682100  22097504  34901461    1  2173-08-23 01:12:00
# 3    15545849  24922530  39025631    3  2172-08-02 16:32:00
# 4    10288279  21750307  34078845    1  2114-09-07 20:19:42
#
#            ICU_outtime  gender  age  height  weight  ...  first_PEEP  \
# 0  2172-04-09 08:17:22       1   66   178.0   113.3  ...         5.0
# 1  2165-01-03 21:30:54       1   53     NaN   106.7  ...         5.0
# 2  2173-08-27 21:28:52       0   66     NaN    46.1  ...       460.0
# 3  2172-09-09 12:44:11       1   49   183.0   106.0  ...         5.0
# 4  2114-09-15 13:24:09       0   77     NaN    49.3  ...         8.0
#
#       std_PEEP  first_PIP    std_PIP  first_mean_airway_pressure  \
# 0   310.799588       26.0   5.971675                        13.0
# 1   284.163626       18.0  11.940840                        12.0
# 2   210.569244       20.0   5.387228                         8.0
# 3  1042.283061       12.0   7.166729                         7.0
# 4   185.553721       21.0   4.283036                        13.0
#
#    std_mean_airway_pressure  first_plateau_pressure  std_plateau_pressure  \
# 0                  1.923269                    19.0              1.909727
# 1                  6.393488                    10.0              8.337289
# 2                  2.184796                    17.0              1.224745
# 3                  4.233572                    11.0              4.877563
# 4                  1.405487                    17.0              3.239768
#
#    vent_duration_hours  outcome
# 0                 96.0        2
# 1                230.0        1
# 2                 34.0        1
# 3                399.0        2
# 4                155.0        2
#
# [5 rows x 120 columns]

# %% [markdown]
# ---
#
# ## 2) Initial exploration: size + column index table
#
# We check:
# - number of rows and columns
# - a **table** with: column index, column name, dtype
#
# This is useful because some steps (e.g., comorbidity encoding) use **column indices**.

# %%
print("Initial shapes of the dataset (rows, cols):", df.shape)

col_table = pd.DataFrame({
    "col_index": np.arange(df.shape[1]),
    "col_name": df.columns.astype(str),
    "dtype": df.dtypes.astype(str)
})

#If you want to display all the columns, de-comment the following instruction
pd.set_option("display.max_rows", None)

display(col_table)
# Out:
# Initial shapes of the dataset (rows, cols): (4000, 120)
#                                  col_index                         col_name  \
# subject_id                               0                       subject_id
# hadm_id                                  1                          hadm_id
# stay_id                                  2                          stay_id
# ICU                                      3                              ICU
# ICU_intime                               4                       ICU_intime
# ICU_outtime                              5                      ICU_outtime
# gender                                   6                           gender
# age                                      7                              age
# height                                   8                           height
# weight                                   9                           weight
# adrenal_disorders                       10                adrenal_disorders
# aids                                    11                             aids
# alcohol_abuse                           12                    alcohol_abuse
# asthma                                  13                           asthma
# blood_loss_anemia                       14                blood_loss_anemia
# cardiac_arrhythmia                      15               cardiac_arrhythmia
# central_nervous_system_lymphoma         16  central_nervous_system_lymphoma
# cerebrovascular_disease                 17          cerebrovascular_disease
# chronic_kidney_disease                  18           chronic_kidney_disease
# chronic_pulmonary_disease               19        chronic_pulmonary_disease
# cirrhosis                               20                        cirrhosis
# congestive_heart_failure                21         congestive_heart_failure
# coronary_artery_disease                 22          coronary_artery_disease
# deficiency_anemia                       23                deficiency_anemia
# dementia                                24                         dementia
# depression                              25                       depression
# diabetes_without_complications          26   diabetes_without_complications
# diabetes_with_complications             27      diabetes_with_complications
# drug_abuse                              28                       drug_abuse
# fluid_electrolyte_disorders             29      fluid_electrolyte_disorders
# paraplegia                              30                       paraplegia
# hypertension                            31                     hypertension
# immunosuppression                       32                immunosuppression
# interstitial_lung_disease               33        interstitial_lung_disease
# mild_liver_disease                      34               mild_liver_disease
# severe_liver_disease                    35             severe_liver_disease
# malignant_tumor                         36                  malignant_tumor
# malnutrition                            37                     malnutrition
# metastatic_solid_tumor                  38           metastatic_solid_tumor
# myocardial_infarction                   39            myocardial_infarction
# neuromuscular_disease                   40            neuromuscular_disease
# obesity                                 41                          obesity
# peptic_ulcer_disease                    42             peptic_ulcer_disease
# peripheral_vascular_disease             43      peripheral_vascular_disease
# peripheral_neuropathy                   44            peripheral_neuropathy
# pulmonary_circulatory_disease           45    pulmonary_circulatory_disease
# pulmonary_hypertension                  46           pulmonary_hypertension
# rheumatic_disease                       47                rheumatic_disease
# renal_failure                           48                    renal_failure
# seizure                                 49                          seizure
# sleep_apnea_OSAS                        50                 sleep_apnea_OSAS
# smoke                                   51                            smoke
# stroke                                  52                           stroke
# thyroid_disorders                       53                thyroid_disorders
# valvular_disease                        54                 valvular_disease
# charlson_comorbidity_index              55       charlson_comorbidity_index
# gcs                                     56                              gcs
# sofa                                    57                             sofa
# sirs                                    58                             sirs
# sapsii                                  59                           sapsii
# vasopressors                            60                     vasopressors
# sedatives                               61                        sedatives
# neuromuscular_blockers                  62           neuromuscular_blockers
# steroids                                63                         steroids
# opioids                                 64                          opioids
# sedative_duration_hours                 65          sedative_duration_hours
# first_pCO2                              66                       first_pCO2
# std_pCO2                                67                         std_pCO2
# first_pH                                68                         first_pH
# std_pH                                  69                           std_pH
# first_pO2                               70                        first_pO2
# std_pO2                                 71                          std_pO2
# first_lactate                           72                    first_lactate
# std_lactate                             73                      std_lactate
# first_PT                                74                         first_PT
# std_PT                                  75                           std_PT
# first_PTT                               76                        first_PTT
# std_PTT                                 77                          std_PTT
# first_bilirubin                         78                  first_bilirubin
# std_bilirubin                           79                    std_bilirubin
# first_chloride                          80                   first_chloride
# std_chloride                            81                     std_chloride
# first_creatinine                        82                 first_creatinine
# std_creatinine                          83                   std_creatinine
# first_glycemia                          84                   first_glycemia
# std_glycemia                            85                     std_glycemia
# first_hemoglobin                        86                 first_hemoglobin
# std_hemoglobin                          87                   std_hemoglobin
# first_phosphate                         88                  first_phosphate
# std_phosphate                           89                    std_phosphate
# first_platelets                         90                  first_platelets
# std_platelets                           91                    std_platelets
# first_potassium                         92                  first_potassium
# std_potassium                           93                    std_potassium
# first_sodium                            94                     first_sodium
# std_sodium                              95                       std_sodium
# first_wbc                               96                        first_wbc
# std_wbc                                 97                          std_wbc
# first_diastolic_blood_pressure          98   first_diastolic_blood_pressure
# std_diastolic_blood_pressure            99     std_diastolic_blood_pressure
# first_mean_blood_pressure              100        first_mean_blood_pressure
# std_mean_blood_pressure                101          std_mean_blood_pressure
# first_systolic_blood_pressure          102    first_systolic_blood_pressure
# std_systolic_blood_pressure            103      std_systolic_blood_pressure
# first_heart_rate                       104                 first_heart_rate
# std_heart_rate                         105                   std_heart_rate
# first_respiratory_rate                 106           first_respiratory_rate
# std_respiratory_rate                   107             std_respiratory_rate
# first_temperature                      108                first_temperature
# std_temperature                        109                  std_temperature
# first_PEEP                             110                       first_PEEP
# std_PEEP                               111                         std_PEEP
# first_PIP                              112                        first_PIP
# std_PIP                                113                          std_PIP
# first_mean_airway_pressure             114       first_mean_airway_pressure
# std_mean_airway_pressure               115         std_mean_airway_pressure
# first_plateau_pressure                 116           first_plateau_pressure
# std_plateau_pressure                   117             std_plateau_pressure
# vent_duration_hours                    118              vent_duration_hours
# outcome                                119                          outcome
#
#                                    dtype
# subject_id                         int64
# hadm_id                            int64
# stay_id                            int64
# ICU                                int64
# ICU_intime                        object
# ICU_outtime                       object
# gender                             int64
# age                                int64
# height                           float64
# weight                           float64
# adrenal_disorders                  int64
# aids                               int64
# alcohol_abuse                      int64
# asthma                             int64
# blood_loss_anemia                  int64
# cardiac_arrhythmia                 int64
# central_nervous_system_lymphoma    int64
# cerebrovascular_disease            int64
# chronic_kidney_disease             int64
# chronic_pulmonary_disease          int64
# cirrhosis                          int64
# congestive_heart_failure           int64
# coronary_artery_disease            int64
# deficiency_anemia                  int64
# dementia                           int64
# depression                         int64
# diabetes_without_complications     int64
# diabetes_with_complications        int64
# drug_abuse                         int64
# fluid_electrolyte_disorders        int64
# paraplegia                         int64
# hypertension                       int64
# immunosuppression                  int64
# interstitial_lung_disease          int64
# mild_liver_disease                 int64
# severe_liver_disease               int64
# malignant_tumor                    int64
# malnutrition                       int64
# metastatic_solid_tumor             int64
# myocardial_infarction              int64
# neuromuscular_disease              int64
# obesity                            int64
# peptic_ulcer_disease               int64
# peripheral_vascular_disease        int64
# peripheral_neuropathy              int64
# pulmonary_circulatory_disease      int64
# pulmonary_hypertension             int64
# rheumatic_disease                  int64
# renal_failure                      int64
# seizure                            int64
# sleep_apnea_OSAS                   int64
# smoke                              int64
# stroke                             int64
# thyroid_disorders                  int64
# valvular_disease                   int64
# charlson_comorbidity_index         int64
# gcs                                int64
# sofa                               int64
# sirs                               int64
# sapsii                             int64
# vasopressors                       int64
# sedatives                          int64
# neuromuscular_blockers             int64
# steroids                           int64
# opioids                            int64
# sedative_duration_hours            int64
# first_pCO2                       float64
# std_pCO2                         float64
# first_pH                         float64
# std_pH                           float64
# first_pO2                        float64
# std_pO2                          float64
# first_lactate                    float64
# std_lactate                      float64
# first_PT                         float64
# std_PT                           float64
# first_PTT                        float64
# std_PTT                          float64
# first_bilirubin                  float64
# std_bilirubin                    float64
# first_chloride                     int64
# std_chloride                     float64
# first_creatinine                 float64
# std_creatinine                   float64
# first_glycemia                   float64
# std_glycemia                     float64
# first_hemoglobin                 float64
# std_hemoglobin                   float64
# first_phosphate                  float64
# std_phosphate                    float64
# first_platelets                    int64
# std_platelets                    float64
# first_potassium                  float64
# std_potassium                    float64
# first_sodium                       int64
# std_sodium                       float64
# first_wbc                        float64
# std_wbc                          float64
# first_diastolic_blood_pressure   float64
# std_diastolic_blood_pressure     float64
# first_mean_blood_pressure        float64
# std_mean_blood_pressure          float64
# first_systolic_blood_pressure    float64
# std_systolic_blood_pressure      float64
# first_heart_rate                 float64
# std_heart_rate                   float64
# first_respiratory_rate           float64
# std_respiratory_rate             float64
# first_temperature                float64
# std_temperature                  float64
# first_PEEP                       float64
# std_PEEP                         float64
# first_PIP                        float64
# std_PIP                          float64
# first_mean_airway_pressure       float64
# std_mean_airway_pressure         float64
# first_plateau_pressure           float64
# std_plateau_pressure             float64
# vent_duration_hours              float64
# outcome                            int64

# %% [markdown]
# ---
#
# ## 3) Missing values per variable (column) + drop with threshold
#
# We compute missing values **per column** and optionally drop columns with too many missing values.
# We want to drop the features with at lest

# %%
# STEP 1 — Remove columns with at least 5% missing values

# Set the threshold
col_missing_threshold = 0.05

# Compute missing count and missing percentage for each column
missing_count = df.isnull().sum()
missing_perc = df.isnull().mean()

#  Identify columns to drop (missing % > threshold)
cols_to_drop = missing_perc[missing_perc >= col_missing_threshold].index.tolist()

print(f"Columns to drop (>={col_missing_threshold*100:.0f}% missing):", len(cols_to_drop))
print("Variables eliminadas:", cols_to_drop)

# 5) Create df_1 by dropping those columns
df_1 = df.drop(columns=cols_to_drop)

print("\n--- COMPARACIÓN DE COMENTARIOS ---")
print("Initial shapes of the dataset (rows, cols):", df.shape)
print("Obtained shapes of the dataset (rows, cols):", df_1.shape)
# Out:
# Columns to drop (>=5% missing): 5
# Variables eliminadas: ['height', 'first_lactate', 'std_lactate', 'first_bilirubin', 'std_bilirubin']
#
# --- COMPARACIÓN DE COMENTARIOS ---
# Initial shapes of the dataset (rows, cols): (4000, 120)
# Obtained shapes of the dataset (rows, cols): (4000, 115)

# %% [markdown]
# ---
#
# ## 4) Missing values per subject (row) + drop with threshold
#
# Now we analyze missing values **per row** (per patient/subject).
# We want to drop the subjects with at least 5% of MVs.
#
# > Note: You may want to compute missing rate only on **feature columns** (not IDs/outcome). If needed, adapt the code.

# %%
# STEP 2 — Remove rows (patients) with at least 5% missing values

# Set the threshold
row_missing_threshold = 0.05

# Identificamos cuáles son las columnas de características (features)
# Recordando: quitamos las primeras 6 (IDs) y la última (Outcome)
feature_cols = df_1.columns[6:-1]

# Compute missing percentage for each row in df_1(solo usando las características)
# axis=1 significa que sumamos/promediamos de forma horizontal (por filas)
row_missing_perc = df_1[feature_cols].isnull().mean(axis=1)

# Visualize a quick summary (optional but recommended)

# Identify rows to drop (missing % >= threshold)
# Usamos el índice de las filas que cumplen la condición
rows_to_drop = row_missing_perc[row_missing_perc >= row_missing_threshold].index.tolist()
print(f"Rows to drop (>={row_missing_threshold*100:.0f}% missing):", len(rows_to_drop))

# Create df_2 by dropping those rows and resetting the index
# axis=0 elimina filas. .reset_index(drop=True) reordena los números de fila del 0 en adelante
df_2 = df_1.drop(index=rows_to_drop).reset_index(drop=True)

print("\n--- COMPARACIÓN DE COMENTARIOS ---")
print("Initial shapes of the dataset (rows, cols):", df_1.shape)
print("Obtained shapes of the dataset (rows, cols):", df_2.shape)
# Out:
# Rows to drop (>=5% missing): 107
#
# --- COMPARACIÓN DE COMENTARIOS ---
# Initial shapes of the dataset (rows, cols): (4000, 115)
# Obtained shapes of the dataset (rows, cols): (3893, 115)

# %% [markdown]
# ---
#
# ## 5) Encode comorbidities into categories
#
# We aggregate the original comorbidity columns (0/1) into:
# - `comorb_total`: total number of comorbidities
# - `comorb_cat1` … `comorb_cat5`: 1 if **at least one** comorbidity is present in that category
#
# The five categories are:
# 1. Cardiac and cardiovascular diseases
# 2. Respiratory and pulmonary diseases
# 3. Metabolic, endocrine and renal diseases
# 4. Neurological, neuromuscolar and phychiatric disorders
# 5. System, immunologic and oncologic conditions.
#
# Finally, we **drop** the original comorbidity columns.
#
# ⚠️ Update indices if the final column order changes.

# %%
# 1. Configurar Pandas para que muestre TODAS las filas sin recortar
pd.set_option("display.max_rows", None)

# 2. Construir la tabla de inventario con df_2 (que es tu copia limpia)
col_table = pd.DataFrame({
    "col_index": np.arange(df_2.shape[1]),
    "col_name": df_2.columns.astype(str),
    "dtype": df_2.dtypes.astype(str)
})

# 3. Mostrar la tabla en pantalla
display(col_table)
# Out:
#                                  col_index                         col_name  \
# subject_id                               0                       subject_id
# hadm_id                                  1                          hadm_id
# stay_id                                  2                          stay_id
# ICU                                      3                              ICU
# ICU_intime                               4                       ICU_intime
# ICU_outtime                              5                      ICU_outtime
# gender                                   6                           gender
# age                                      7                              age
# weight                                   8                           weight
# adrenal_disorders                        9                adrenal_disorders
# aids                                    10                             aids
# alcohol_abuse                           11                    alcohol_abuse
# asthma                                  12                           asthma
# blood_loss_anemia                       13                blood_loss_anemia
# cardiac_arrhythmia                      14               cardiac_arrhythmia
# central_nervous_system_lymphoma         15  central_nervous_system_lymphoma
# cerebrovascular_disease                 16          cerebrovascular_disease
# chronic_kidney_disease                  17           chronic_kidney_disease
# chronic_pulmonary_disease               18        chronic_pulmonary_disease
# cirrhosis                               19                        cirrhosis
# congestive_heart_failure                20         congestive_heart_failure
# coronary_artery_disease                 21          coronary_artery_disease
# deficiency_anemia                       22                deficiency_anemia
# dementia                                23                         dementia
# depression                              24                       depression
# diabetes_without_complications          25   diabetes_without_complications
# diabetes_with_complications             26      diabetes_with_complications
# drug_abuse                              27                       drug_abuse
# fluid_electrolyte_disorders             28      fluid_electrolyte_disorders
# paraplegia                              29                       paraplegia
# hypertension                            30                     hypertension
# immunosuppression                       31                immunosuppression
# interstitial_lung_disease               32        interstitial_lung_disease
# mild_liver_disease                      33               mild_liver_disease
# severe_liver_disease                    34             severe_liver_disease
# malignant_tumor                         35                  malignant_tumor
# malnutrition                            36                     malnutrition
# metastatic_solid_tumor                  37           metastatic_solid_tumor
# myocardial_infarction                   38            myocardial_infarction
# neuromuscular_disease                   39            neuromuscular_disease
# obesity                                 40                          obesity
# peptic_ulcer_disease                    41             peptic_ulcer_disease
# peripheral_vascular_disease             42      peripheral_vascular_disease
# peripheral_neuropathy                   43            peripheral_neuropathy
# pulmonary_circulatory_disease           44    pulmonary_circulatory_disease
# pulmonary_hypertension                  45           pulmonary_hypertension
# rheumatic_disease                       46                rheumatic_disease
# renal_failure                           47                    renal_failure
# seizure                                 48                          seizure
# sleep_apnea_OSAS                        49                 sleep_apnea_OSAS
# smoke                                   50                            smoke
# stroke                                  51                           stroke
# thyroid_disorders                       52                thyroid_disorders
# valvular_disease                        53                 valvular_disease
# charlson_comorbidity_index              54       charlson_comorbidity_index
# gcs                                     55                              gcs
# sofa                                    56                             sofa
# sirs                                    57                             sirs
# sapsii                                  58                           sapsii
# vasopressors                            59                     vasopressors
# sedatives                               60                        sedatives
# neuromuscular_blockers                  61           neuromuscular_blockers
# steroids                                62                         steroids
# opioids                                 63                          opioids
# sedative_duration_hours                 64          sedative_duration_hours
# first_pCO2                              65                       first_pCO2
# std_pCO2                                66                         std_pCO2
# first_pH                                67                         first_pH
# std_pH                                  68                           std_pH
# first_pO2                               69                        first_pO2
# std_pO2                                 70                          std_pO2
# first_PT                                71                         first_PT
# std_PT                                  72                           std_PT
# first_PTT                               73                        first_PTT
# std_PTT                                 74                          std_PTT
# first_chloride                          75                   first_chloride
# std_chloride                            76                     std_chloride
# first_creatinine                        77                 first_creatinine
# std_creatinine                          78                   std_creatinine
# first_glycemia                          79                   first_glycemia
# std_glycemia                            80                     std_glycemia
# first_hemoglobin                        81                 first_hemoglobin
# std_hemoglobin                          82                   std_hemoglobin
# first_phosphate                         83                  first_phosphate
# std_phosphate                           84                    std_phosphate
# first_platelets                         85                  first_platelets
# std_platelets                           86                    std_platelets
# first_potassium                         87                  first_potassium
# std_potassium                           88                    std_potassium
# first_sodium                            89                     first_sodium
# std_sodium                              90                       std_sodium
# first_wbc                               91                        first_wbc
# std_wbc                                 92                          std_wbc
# first_diastolic_blood_pressure          93   first_diastolic_blood_pressure
# std_diastolic_blood_pressure            94     std_diastolic_blood_pressure
# first_mean_blood_pressure               95        first_mean_blood_pressure
# std_mean_blood_pressure                 96          std_mean_blood_pressure
# first_systolic_blood_pressure           97    first_systolic_blood_pressure
# std_systolic_blood_pressure             98      std_systolic_blood_pressure
# first_heart_rate                        99                 first_heart_rate
# std_heart_rate                         100                   std_heart_rate
# first_respiratory_rate                 101           first_respiratory_rate
# std_respiratory_rate                   102             std_respiratory_rate
# first_temperature                      103                first_temperature
# std_temperature                        104                  std_temperature
# first_PEEP                             105                       first_PEEP
# std_PEEP                               106                         std_PEEP
# first_PIP                              107                        first_PIP
# std_PIP                                108                          std_PIP
# first_mean_airway_pressure             109       first_mean_airway_pressure
# std_mean_airway_pressure               110         std_mean_airway_pressure
# first_plateau_pressure                 111           first_plateau_pressure
# std_plateau_pressure                   112             std_plateau_pressure
# vent_duration_hours                    113              vent_duration_hours
# outcome                                114                          outcome
#
#                                    dtype
# subject_id                         int64
# hadm_id                            int64
# stay_id                            int64
# ICU                                int64
# ICU_intime                        object
# ICU_outtime                       object
# gender                             int64
# age                                int64
# weight                           float64
# adrenal_disorders                  int64
# aids                               int64
# alcohol_abuse                      int64
# asthma                             int64
# blood_loss_anemia                  int64
# cardiac_arrhythmia                 int64
# central_nervous_system_lymphoma    int64
# cerebrovascular_disease            int64
# chronic_kidney_disease             int64
# chronic_pulmonary_disease          int64
# cirrhosis                          int64
# congestive_heart_failure           int64
# coronary_artery_disease            int64
# deficiency_anemia                  int64
# dementia                           int64
# depression                         int64
# diabetes_without_complications     int64
# diabetes_with_complications        int64
# drug_abuse                         int64
# fluid_electrolyte_disorders        int64
# paraplegia                         int64
# hypertension                       int64
# immunosuppression                  int64
# interstitial_lung_disease          int64
# mild_liver_disease                 int64
# severe_liver_disease               int64
# malignant_tumor                    int64
# malnutrition                       int64
# metastatic_solid_tumor             int64
# myocardial_infarction              int64
# neuromuscular_disease              int64
# obesity                            int64
# peptic_ulcer_disease               int64
# peripheral_vascular_disease        int64
# peripheral_neuropathy              int64
# pulmonary_circulatory_disease      int64
# pulmonary_hypertension             int64
# rheumatic_disease                  int64
# renal_failure                      int64
# seizure                            int64
# sleep_apnea_OSAS                   int64
# smoke                              int64
# stroke                             int64
# thyroid_disorders                  int64
# valvular_disease                   int64
# charlson_comorbidity_index         int64
# gcs                                int64
# sofa                               int64
# sirs                               int64
# sapsii                             int64
# vasopressors                       int64
# sedatives                          int64
# neuromuscular_blockers             int64
# steroids                           int64
# opioids                            int64
# sedative_duration_hours            int64
# first_pCO2                       float64
# std_pCO2                         float64
# first_pH                         float64
# std_pH                           float64
# first_pO2                        float64
# std_pO2                          float64
# first_PT                         float64
# std_PT                           float64
# first_PTT                        float64
# std_PTT                          float64
# first_chloride                     int64
# std_chloride                     float64
# first_creatinine                 float64
# std_creatinine                   float64
# first_glycemia                   float64
# std_glycemia                     float64
# first_hemoglobin                 float64
# std_hemoglobin                   float64
# first_phosphate                  float64
# std_phosphate                    float64
# first_platelets                    int64
# std_platelets                    float64
# first_potassium                  float64
# std_potassium                    float64
# first_sodium                       int64
# std_sodium                       float64
# first_wbc                        float64
# std_wbc                          float64
# first_diastolic_blood_pressure   float64
# std_diastolic_blood_pressure     float64
# first_mean_blood_pressure        float64
# std_mean_blood_pressure          float64
# first_systolic_blood_pressure    float64
# std_systolic_blood_pressure      float64
# first_heart_rate                 float64
# std_heart_rate                   float64
# first_respiratory_rate           float64
# std_respiratory_rate             float64
# first_temperature                float64
# std_temperature                  float64
# first_PEEP                       float64
# std_PEEP                         float64
# first_PIP                        float64
# std_PIP                          float64
# first_mean_airway_pressure       float64
# std_mean_airway_pressure         float64
# first_plateau_pressure           float64
# std_plateau_pressure             float64
# vent_duration_hours              float64
# outcome                            int64

# %%
# Show the index and the header of all the columns to identify the ones related to Comorbidities
col_table = pd.DataFrame({
    "col_index": np.arange(df_2.shape[1]),
    "col_name": df_2.columns.astype(str),
    "dtype": df_2.dtypes.astype(str)
})

pd.set_option("display.max_rows", None)
display(col_table)

# - Identify the first and last comorbidity column indices from the table above
idx_start = 9
idx_end = 53
# Out:
#                                  col_index                         col_name  \
# subject_id                               0                       subject_id
# hadm_id                                  1                          hadm_id
# stay_id                                  2                          stay_id
# ICU                                      3                              ICU
# ICU_intime                               4                       ICU_intime
# ICU_outtime                              5                      ICU_outtime
# gender                                   6                           gender
# age                                      7                              age
# weight                                   8                           weight
# adrenal_disorders                        9                adrenal_disorders
# aids                                    10                             aids
# alcohol_abuse                           11                    alcohol_abuse
# asthma                                  12                           asthma
# blood_loss_anemia                       13                blood_loss_anemia
# cardiac_arrhythmia                      14               cardiac_arrhythmia
# central_nervous_system_lymphoma         15  central_nervous_system_lymphoma
# cerebrovascular_disease                 16          cerebrovascular_disease
# chronic_kidney_disease                  17           chronic_kidney_disease
# chronic_pulmonary_disease               18        chronic_pulmonary_disease
# cirrhosis                               19                        cirrhosis
# congestive_heart_failure                20         congestive_heart_failure
# coronary_artery_disease                 21          coronary_artery_disease
# deficiency_anemia                       22                deficiency_anemia
# dementia                                23                         dementia
# depression                              24                       depression
# diabetes_without_complications          25   diabetes_without_complications
# diabetes_with_complications             26      diabetes_with_complications
# drug_abuse                              27                       drug_abuse
# fluid_electrolyte_disorders             28      fluid_electrolyte_disorders
# paraplegia                              29                       paraplegia
# hypertension                            30                     hypertension
# immunosuppression                       31                immunosuppression
# interstitial_lung_disease               32        interstitial_lung_disease
# mild_liver_disease                      33               mild_liver_disease
# severe_liver_disease                    34             severe_liver_disease
# malignant_tumor                         35                  malignant_tumor
# malnutrition                            36                     malnutrition
# metastatic_solid_tumor                  37           metastatic_solid_tumor
# myocardial_infarction                   38            myocardial_infarction
# neuromuscular_disease                   39            neuromuscular_disease
# obesity                                 40                          obesity
# peptic_ulcer_disease                    41             peptic_ulcer_disease
# peripheral_vascular_disease             42      peripheral_vascular_disease
# peripheral_neuropathy                   43            peripheral_neuropathy
# pulmonary_circulatory_disease           44    pulmonary_circulatory_disease
# pulmonary_hypertension                  45           pulmonary_hypertension
# rheumatic_disease                       46                rheumatic_disease
# renal_failure                           47                    renal_failure
# seizure                                 48                          seizure
# sleep_apnea_OSAS                        49                 sleep_apnea_OSAS
# smoke                                   50                            smoke
# stroke                                  51                           stroke
# thyroid_disorders                       52                thyroid_disorders
# valvular_disease                        53                 valvular_disease
# charlson_comorbidity_index              54       charlson_comorbidity_index
# gcs                                     55                              gcs
# sofa                                    56                             sofa
# sirs                                    57                             sirs
# sapsii                                  58                           sapsii
# vasopressors                            59                     vasopressors
# sedatives                               60                        sedatives
# neuromuscular_blockers                  61           neuromuscular_blockers
# steroids                                62                         steroids
# opioids                                 63                          opioids
# sedative_duration_hours                 64          sedative_duration_hours
# first_pCO2                              65                       first_pCO2
# std_pCO2                                66                         std_pCO2
# first_pH                                67                         first_pH
# std_pH                                  68                           std_pH
# first_pO2                               69                        first_pO2
# std_pO2                                 70                          std_pO2
# first_PT                                71                         first_PT
# std_PT                                  72                           std_PT
# first_PTT                               73                        first_PTT
# std_PTT                                 74                          std_PTT
# first_chloride                          75                   first_chloride
# std_chloride                            76                     std_chloride
# first_creatinine                        77                 first_creatinine
# std_creatinine                          78                   std_creatinine
# first_glycemia                          79                   first_glycemia
# std_glycemia                            80                     std_glycemia
# first_hemoglobin                        81                 first_hemoglobin
# std_hemoglobin                          82                   std_hemoglobin
# first_phosphate                         83                  first_phosphate
# std_phosphate                           84                    std_phosphate
# first_platelets                         85                  first_platelets
# std_platelets                           86                    std_platelets
# first_potassium                         87                  first_potassium
# std_potassium                           88                    std_potassium
# first_sodium                            89                     first_sodium
# std_sodium                              90                       std_sodium
# first_wbc                               91                        first_wbc
# std_wbc                                 92                          std_wbc
# first_diastolic_blood_pressure          93   first_diastolic_blood_pressure
# std_diastolic_blood_pressure            94     std_diastolic_blood_pressure
# first_mean_blood_pressure               95        first_mean_blood_pressure
# std_mean_blood_pressure                 96          std_mean_blood_pressure
# first_systolic_blood_pressure           97    first_systolic_blood_pressure
# std_systolic_blood_pressure             98      std_systolic_blood_pressure
# first_heart_rate                        99                 first_heart_rate
# std_heart_rate                         100                   std_heart_rate
# first_respiratory_rate                 101           first_respiratory_rate
# std_respiratory_rate                   102             std_respiratory_rate
# first_temperature                      103                first_temperature
# std_temperature                        104                  std_temperature
# first_PEEP                             105                       first_PEEP
# std_PEEP                               106                         std_PEEP
# first_PIP                              107                        first_PIP
# std_PIP                                108                          std_PIP
# first_mean_airway_pressure             109       first_mean_airway_pressure
# std_mean_airway_pressure               110         std_mean_airway_pressure
# first_plateau_pressure                 111           first_plateau_pressure
# std_plateau_pressure                   112             std_plateau_pressure
# vent_duration_hours                    113              vent_duration_hours
# outcome                                114                          outcome
#
#                                    dtype
# subject_id                         int64
# hadm_id                            int64
# stay_id                            int64
# ICU                                int64
# ICU_intime                        object
# ICU_outtime                       object
# gender                             int64
# age                                int64
# weight                           float64
# adrenal_disorders                  int64
# aids                               int64
# alcohol_abuse                      int64
# asthma                             int64
# blood_loss_anemia                  int64
# cardiac_arrhythmia                 int64
# central_nervous_system_lymphoma    int64
# cerebrovascular_disease            int64
# chronic_kidney_disease             int64
# chronic_pulmonary_disease          int64
# cirrhosis                          int64
# congestive_heart_failure           int64
# coronary_artery_disease            int64
# deficiency_anemia                  int64
# dementia                           int64
# depression                         int64
# diabetes_without_complications     int64
# diabetes_with_complications        int64
# drug_abuse                         int64
# fluid_electrolyte_disorders        int64
# paraplegia                         int64
# hypertension                       int64
# immunosuppression                  int64
# interstitial_lung_disease          int64
# mild_liver_disease                 int64
# severe_liver_disease               int64
# malignant_tumor                    int64
# malnutrition                       int64
# metastatic_solid_tumor             int64
# myocardial_infarction              int64
# neuromuscular_disease              int64
# obesity                            int64
# peptic_ulcer_disease               int64
# peripheral_vascular_disease        int64
# peripheral_neuropathy              int64
# pulmonary_circulatory_disease      int64
# pulmonary_hypertension             int64
# rheumatic_disease                  int64
# renal_failure                      int64
# seizure                            int64
# sleep_apnea_OSAS                   int64
# smoke                              int64
# stroke                             int64
# thyroid_disorders                  int64
# valvular_disease                   int64
# charlson_comorbidity_index         int64
# gcs                                int64
# sofa                               int64
# sirs                               int64
# sapsii                             int64
# vasopressors                       int64
# sedatives                          int64
# neuromuscular_blockers             int64
# steroids                           int64
# opioids                            int64
# sedative_duration_hours            int64
# first_pCO2                       float64
# std_pCO2                         float64
# first_pH                         float64
# std_pH                           float64
# first_pO2                        float64
# std_pO2                          float64
# first_PT                         float64
# std_PT                           float64
# first_PTT                        float64
# std_PTT                          float64
# first_chloride                     int64
# std_chloride                     float64
# first_creatinine                 float64
# std_creatinine                   float64
# first_glycemia                   float64
# std_glycemia                     float64
# first_hemoglobin                 float64
# std_hemoglobin                   float64
# first_phosphate                  float64
# std_phosphate                    float64
# first_platelets                    int64
# std_platelets                    float64
# first_potassium                  float64
# std_potassium                    float64
# first_sodium                       int64
# std_sodium                       float64
# first_wbc                        float64
# std_wbc                          float64
# first_diastolic_blood_pressure   float64
# std_diastolic_blood_pressure     float64
# first_mean_blood_pressure        float64
# std_mean_blood_pressure          float64
# first_systolic_blood_pressure    float64
# std_systolic_blood_pressure      float64
# first_heart_rate                 float64
# std_heart_rate                   float64
# first_respiratory_rate           float64
# std_respiratory_rate             float64
# first_temperature                float64
# std_temperature                  float64
# first_PEEP                       float64
# std_PEEP                         float64
# first_PIP                        float64
# std_PIP                          float64
# first_mean_airway_pressure       float64
# std_mean_airway_pressure         float64
# first_plateau_pressure           float64
# std_plateau_pressure             float64
# vent_duration_hours              float64
# outcome                            int64

# %%
# ================== COMORBIDITY GROUPS ==================
# 0 = absent, 1 = present
# Check the names before running the code: typos can be present!

comorbidity_categories = {
    1: ["cardiac_arrhythmia","congestive_heart_failure","coronary_artery_disease","hypertension","myocardial_infarction","peripheral_vascular_disease","valvular_disease"],
    2: ["asthma","chronic_pulmonary_disease","interstitial_lung_disease","pulmonary_circulatory_disease","pulmonary_hypertension","sleep_apnea_OSAS"],
    3: ["adrenal_disorders","chronic_kidney_disease","cirrhosis","diabetes_with_complications","diabetes_without_complications","fluid_electrolyte_disorders","mild_liver_disease","severe_liver_disease","malnutrition","obesity","peptic_ulcer_disease","renal_failure","thyroid_disorders"],
    4: ["alcohol_abuse","central_nervous_system_lymphoma","cerebrovascular_disease","dementia","depression","drug_abuse","paraplegia","neuromuscular_disease","peripheral_neuropathy","seizure","smoke","stroke"],
    5: ["aids","blood_loss_anemia","deficiency_anemia","immunosuppression","malignant_tumor","metastatic_solid_tumor","rheumatic_disease"]
}

cat_name = {
    1: "cardiac_cardiovascular",
    2: "respiratory_pulmonary",
    3: "metabolic_endocrine_renal",
    4: "neurological_neuromuscular_psychiatric",
    5: "systemic_immune_oncologic"
}

# ================== CONSISTENCY CHECK ==================
missing_vars = {}

for cat, vars_list in comorbidity_categories.items():
    missing = [v for v in vars_list if v not in df_2.columns]
    if missing:
        missing_vars[cat] = missing

if not missing_vars:
    print("All comorbidity variables were found in the dataset.")
else:
    print("Some comorbidity variables were NOT found in the dataset:")
    for cat, vars_list in missing_vars.items():
        print(f"  Category {cat}: {vars_list}")
# Out:
# All comorbidity variables were found in the dataset.

# %%
# STEP 4 — Comorbidity encoding (aggregation into groups)
# Goal: Create 5 new columns (0/1):
# - 1 if at least one comorbidity in that group is 1
# - 0 otherwise
df_3 = df_2.copy()

# Identify the absence/presence of each category
# Recorremos el diccionario para crear las 5 nuevas columnas resumidas
for cat_id, vars_list in comorbidity_categories.items():
    new_col_name = f"comorb_{cat_name[cat_id]}"

    # .any(axis=1) verifica si hay AL MENOS UN valor verdadero (o un 1) en esa fila para ese grupo
    # .astype(int) transforma ese True/False en 1 o 0
    df_3[new_col_name] = df_2[vars_list].any(axis=1).astype(int)

# Remove the original comorbidity columns
# Usamos los índices idx_start (9) e idx_end (53) que encontramos en tu tabla para el bloque completo
original_comorb_cols = df_2.columns[idx_start:idx_end+1]
df_3 = df_3.drop(columns=original_comorb_cols)

print("Dataset shape after comorbidity grouping:", df_3.shape)
# Out:
# Dataset shape after comorbidity grouping: (3893, 75)

# %% [markdown]
# ---
#
# ## 6) Final saving
#
# Save the prepared dataset for the next steps/labs.
#
# Choose one of the formats below.

# %%
# OPTIONAL — Save the obtained dataset in a new sheet of the original .xlsx file
# Create jsut a new SHEET (not file) named "Dataset_v1"

# Definimos el nombre del archivo de salida (puedes usar el mismo original)
out_xlsx = 'Dataset_DAPPC_2026_Cleaned.xlsx'
sheet_out = 'Dataset_v1'

# Usamos ExcelWriter con el motor openpyxl para agregar la hoja
# Si el archivo no existe, lo creará. Si existe, añadirá la hoja.
with pd.ExcelWriter(out_xlsx, engine='openpyxl') as writer:
    df_3.to_excel(writer, sheet_name=sheet_out, index=False)

print(f"¡Éxito! El dataset preparado se ha guardado en el archivo: {out_xlsx}")
print(f"En la hoja: {sheet_out}")
# Out:
# ¡Éxito! El dataset preparado se ha guardado en el archivo: Dataset_DAPPC_2026_Cleaned.xlsx
# En la hoja: Dataset_v1
